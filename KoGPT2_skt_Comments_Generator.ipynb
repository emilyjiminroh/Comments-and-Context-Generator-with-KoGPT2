# %% [markdown]
# <a href="https://colab.research.google.com/github/emilyjiminroh/Comments-and-Context-Generator-with-KoGPT2/blob/main/KoGPT2_skt_Comments_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## YouTube API Package
# - Get API key: https://console.developers.google.com/
# - python-youtube: https://pypi.org/project/python-youtube/
# - YouTube commentThreads API doc: https://developers.google.com/youtube/v3/docs/commentThreads/list

# %%
# !pip install python-youtube
from pyyoutube import Api #Python youtube package

api_key = '''Your API Key'''
api = Api(api_key=api_key)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 42 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 41 kB 786 kB/s
# ...
#      |████████████████████████████████| 62 kB 2.0 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
ct_by_all = api.get_comment_threads(
    all_to_channel_id="UChY4PXxJI0aJYsGT1X6INWA",
    count=500)

ct_by_all
# Out:
# CommentThreadListResponse(kind='youtube#commentThreadListResponse')

# %%
len(ct_by_all.items)
# Out:
# 500

# %%
ct_by_all.items[-10].snippet.topLevelComment.snippet.textOriginal
# Out:
# '10:53 진짜 개 멋있다'

# %%
with open('comments.txt', 'w') as f:
    for item in ct_by_all.items:
        comment = item.snippet.topLevelComment.snippet.textOriginal.replace('\n', ' ').replace('\r', ' ')
        f.write(comment + '\n')

# %%
import requests
import json

# %%
r= requests.post(
  'https://train-8eao9zoqea4d62920v6w-gpt2-train-teachable-ainize.endpoint.ainize.ai/predictions/gpt-2-ko-small-finetune',
  headers={
    'Content-Type':'application/json'
  },
  data=json.dumps({
    'text':'무한도전은',
    'num_samples':100,
    'length':32
  }))

r.json()
# Out:
# ['무한도전은 계속되죠\n김한수 - ᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏ\n김재철 - 뭔가 다른게',
#  '무한도전은 아니지 ᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏ',
#  '무한도전은 재밌네\n이제 우리집에는 어이가 없었느냐\n진짜는 너무 웃겨서 진짜 엄청 웃겼다\n왜냐하면 저',
#  '무한도전은 너무 심심했나봐ᄏᄏᄏᄏᄏᄏ\n#_6:23.. ᄏᄏᄏᄏ\n',
#  '무한도전은 또 볼수가 없네 이거 정말 신기하네!\n이렇게 무도한테도 섹시하는 사람이 저렇게 나오나?\n또 다른',
#  '무한도전은 끝이 없다고 말하지만 저쪽이 얼마나 강적이냐?"라는 평가가 많다.\n이 때 저는 웃기다.\n웃기죠...아 이게',
#  '무한도전은 성공하는거 아니죠. ᄏᄏᄏᄏᄏᄏ\n그때 이후로 왜 저런 얘기를 했냐 라는 얘기도 한다.\n그',
#  '무한도전은 아니다 뭐 도전하고 싶어?\n도전만하면 아저씨는 완전 미친다 너는 절대전제 다 안될',
#  '무한도전은 또 저거지 ᄏᄏᄏᄏᄏ\n이렇게 웃기네, 재밌네...ᄏᄏᄏᄏ\n마녀사냥',
#  '무한도전은 어떤 의미였을까?" "2PM:Please MCU전개... 그 녀석의 진짜 재밌네!"',
#  '무한도전은 끝났을지 몰라스\n그런데 그땐 이미지, 웃기잖아 ᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏ',
#  '무한도전은 왜 시작도 안했을까?\n이때도 역시 똘끼는 다정했나... ᄏᄏ\n4:28 때부턴',
#  "무한도전은 아니다'라고 말한다.\n그 말을 듣고도 계속 무섭게 떠들어도 안 웃는걸 보면 은근히 재밌긴하네;\n",
#  '무한도전은 끝났다는걸 알게 된다.\n그리고 그 때 이후로는 안 나왔고 그 후론 안 나오는거 보면...? ᄏᄏᄏᄏ',
#  '무한도전은 아니지만 정준하에게 너무 땡박\n제목이 개무시되네 ᄏᄏᄏᄏᄏᄏᄏᄏᄏ\n이',
#  '무한도전은 결국 스쳐가는게 재밌다" ᄏᄏ\n1999년에 \'19년 여름\'이라는 대목을 보면 당시 이미지는 이미 \'최',
# ...

# %%
result = r.json()

for r in result:
  print(r)
# Out:
# 무한도전은 계속되죠
# 김한수 - ᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏ
# 김재철 - 뭔가 다른게
# 무한도전은 아니지 ᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏ
# 무한도전은 재밌네
# 이제 우리집에는 어이가 없었느냐
# 진짜는 너무 웃겨서 진짜 엄청 웃겼다
# 왜냐하면 저
# 무한도전은 너무 심심했나봐ᄏᄏᄏᄏᄏᄏ
# #_6:23.. ᄏᄏᄏᄏ
#
# 무한도전은 또 볼수가 없네 이거 정말 신기하네!
# 이렇게 무도한테도 섹시하는 사람이 저렇게 나오나?
# 또 다른
# 무한도전은 끝이 없다고 말하지만 저쪽이 얼마나 강적이냐?"라는 평가가 많다.
# 이 때 저는 웃기다.
# 웃기죠...아 이게
# 무한도전은 성공하는거 아니죠. ᄏᄏᄏᄏᄏᄏ
# 그때 이후로 왜 저런 얘기를 했냐 라는 얘기도 한다.
# 그
# 무한도전은 아니다 뭐 도전하고 싶어?
# 도전만하면 아저씨는 완전 미친다 너는 절대전제 다 안될
# 무한도전은 또 저거지 ᄏᄏᄏᄏᄏ
# 이렇게 웃기네, 재밌네...ᄏᄏᄏᄏ
# 마녀사냥
# 무한도전은 어떤 의미였을까?" "2PM:Please MCU전개... 그 녀석의 진짜 재밌네!"
# 무한도전은 끝났을지 몰라스
# 그런데 그땐 이미지, 웃기잖아 ᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏᄏ
# 무한도전은 왜 시작도 안했을까?
# 이때도 역시 똘끼는 다정했나... ᄏᄏ
# 4:28 때부턴
# 무한도전은 아니다'라고 말한다.
# 그 말을 듣고도 계속 무섭게 떠들어도 안 웃는걸 보면 은근히 재밌긴하네;
#
# 무한도전은 끝났다는걸 알게 된다.
# 그리고 그 때 이후로는 안 나왔고 그 후론 안 나오는거 보면...? ᄏᄏᄏᄏ
# 무한도전은 아니지만 정준하에게 너무 땡박
# 제목이 개무시되네 ᄏᄏᄏᄏᄏᄏᄏᄏᄏ
# 이
# 무한도전은 결국 스쳐가는게 재밌다" ᄏᄏ
# 1999년에 '19년 여름'이라는 대목을 보면 당시 이미지는 이미 '최
# 무한도전은 그 당시까지도 많은 사람들에게 엄청난 재미를 선사시켰던 프로그램이다.
# 그렇게 재밌는 일이 많았으니까 저런 말 해봤어?
#
# ...
